# %%
print("Hello world")
print('hello world!!!')
# Out:
# Hello world
# hello world!!!

# %%
# !python --version  #yorum satırı sadece 1 satır '''<< metin için kullanılır
# Out:
# Python 3.6.9

# %%
n = 5
print(n) #n isimli değişkenin değerini bastırıyoruz bu yüzden tırnak yok
p=n
print(p)
# Out:
# 5
# 5

# %%
#string
hello="world"

# %%
print(hello)
print("world")
print(n)
# Out:
# world
# world
# 5

# %%
#type
type(hello)
# Out:
# str

# %%
int_value = 5

# %%
print(type (int_value))
# Out:
# <class 'int'>

# %%
#float
t = 3.19
print(type (t))
# Out:
# <class 'float'>

# %%
type ('x')
# Out:
# str

# %%
type (5)
# Out:
# int

# %%
type (3.12)
# Out:
# float

# %%
#boolean
t,f= True, False
print(type (t))
print(type (f))
print(t)
print(f)

# %%
#swapping
data1 = 7
data2 = 12
data3 = 23.5
data4 = 33
data1, data2, data3, data4 = data2, data3, data1, data4
print(data1, data2, data3, data4)
# Out:
# 12 23.5 7 33

# %%
print("data1:", data1, "data2:", data2)
# Out:
# data1: 12 data2: 23.5

# %%
len("Pythoneer") #karakter sayısını verir
# Out:
# 9

# %%
len("Welcome to Turkish AI Hub") #boşlukta bir karakterdir
# Out:
# 25

# %%
hello
# Out:
# 'world'

# %%
print(len (hello))
# Out:
# 5

# %%
len("1")
# Out:
# 1

# %%
data22 = "data science"
len(data22)
# Out:
# 12

# %%
#ef-string
name = "Turkey"
print(f'hello {name}')
# Out:
# hello Turkey

# %%
data12 = 12
str (data12)
# Out:
# '12'

# %%
print("Hello", "world", sep="\n" )
# Out:
# Hello
# world

# %%
data12 = str(data12)

# %%
type(data12)
# Out:
# str

# %%
data12 = 12
type(data12)
# Out:
# int

# %%
5+5
# Out:
# 10

# %%
"5" + "5"
# Out:
# '55'

# %%
print("My value: " + str (data12) + " your value: " + str(data12))
# Out:
# My value: 12 your value: 12

# %%
a=50
type(a)
# Out:
# int

# %%
type(str(a))
# Out:
# str

# %%
float("3")
# Out:
# 3.0

# %%
round(float("3.0"))
# Out:
# 3

# %%
5**2
# Out:
# 25

# %%
5**3
# Out:
# 125

# %%
35+67
# Out:
# 102

# %%
"35"+"67"
# Out:
# '3567'

# %%
"omer "+"cengiz"
# Out:
# 'omer cengiz'

# %%
"35"+ 67 # hata verir str+int olamaz

# %%
"35"*3
# Out:
# '353535'

# %%
"hello"*4
# Out:
# 'hellohellohellohello'

# %%
"hello" "world"
# Out:
# 'helloworld'

# %%
3-5
# Out:
# -2

# %%
x=10

print(x-2)
print(x+5)
print(x*2)
print(x**2)
print(x**4)
print(x/2)
print(x//2) #virgül sonrasını almaz
print(x%2)
# Out:
# 8
# 15
# 20
# 100
# 10000
# 5.0
# 5
# 0

# %%
z= 5
z += 2
z
# Out:
# 7

# %%
z*=2
z
# Out:
# 14

# %%
hello = "hello "
print("hello")
print(hello[0])
print(hello[1])
print(hello[2])
print(hello[3])
print(hello[4])
print(hello[5])
# Out:
# hello
# h
# e
# l
# l
# o

# %%
hello[2:4]
# Out:
# 'll'

# %%
world="world"
world[1:4]
# Out:
# 'orl'

# %%
print(world[3:5])
# Out:
# ld

# %%
print(world[1:3])
# Out:
# ld

# %%
print(world[2:])
# Out:
# rld

# %%
world[2:-4]
# Out:
# ''

# %%
world[2:4:1]  #start : end : stop
# Out:
# 'rl'

# %%
city= "İstanbul"
city[0:7:2]
# Out:
# 'İtnu'

# %%
city[1::3]
# Out:
# 'snl'

# %%
"t" in city
# Out:
# True

# %%
"y" in city
# Out:
# False

# %%
"anb" in city
# Out:
# True

# %%
m= 8
print(float(m))
# Out:
# 8.0

# %%
word = 'machine learning'
print(word.capitalize())
# Out:
# Machine learning

# %%
print(word.upper())
# Out:
# MACHINE LEARNING

# %%
print(word.replace('machine','artificial'))
# Out:
# artificial learning

# %%
word2 = "                      artificial general       intelligence"
print(word2.strip("intelligence"))
# Out:
#                       artificial general

# %%
y= input("please enter a city name: ")
print(y)
# Out:
# please enter a city name: ankara
# ankara

# %%
type (y)
# Out:
# str

# %%
x= int(input("please enter a integer: "))
print(x)
# Out:
# please enter a integer: 45
# 45

# %%
#list
mylist= [3,5,7,8]
print(mylist)
# Out:
# [3, 5, 7, 8]

# %%
print(mylist[0])
print(mylist[1])
print(mylist[2])
print(mylist[-1])
print(mylist[-3])
# Out:
# 3
# 5
# 7
# 8
# 5

# %%
a=10
print(a+10)
# Out:
# 20

# %%
a=5.0
b=a**2
print(b,type (b))
# Out:
# 25.0 <class 'float'>

# %%
a = "10"
b= 15.5
print(len(b) + len(a))

# %%
a="""123
456
789"""
b = "123\n456\n789"
print(a == b)
# Out:
# True
