# %% [markdown]
# # list
# * tanımlama
# * erişim
# * güncelleme
# * ekleme
# * silme
# * yardımcı fonksiyonlar

# %% [markdown]
# List veri tipi dizi olarak kullanılır. Dizinin her bir elemanı nesnedir. Bunun anlamı liste içerisinde her tip değişken (fonksiyon,dosya,sınıf da dahil) bir eleman olarak tutulabilmesidir.

# %% [markdown]
# ## tanımlama

# %%
liste = []
print(type(liste))
# Out:
# <class 'list'>

# %%
liste = [1,2,3,4,5]
print(type(liste))
# Out:
# <class 'list'>

# %%
liste = [1,2,1]
print(type(liste))

# %% [markdown]
# erişim

# %%
liste = [1,2,3,4,5,6,7]
liste[0], liste[-7]
# Out:
# (1, 1)

# %%
liste = [1,2,3,4,5,6,7]
liste[2:6:3]
# Out:
# [3, 6]

# %% [markdown]
# ### pop
#
# pop argüman olarak indis numarası alır, listedeki sildiği elemanı bize geri dönüş değeri olarak döner. Bir başka ifadeyle listede o indiste bulunan elemanın çıkartılmasını sağlar.

# %% [markdown]
# #yardımcı fonksiyonlar

# %% [markdown]
# copy

# %%
a = 1
b = a
b = 2
a,b
# Out:
# (1, 2)

# %%
a = [1,2,3]
b = a
b.append(500)
a,b
# Out:
# ([1, 2, 3, 500], [1, 2, 3, 500])
