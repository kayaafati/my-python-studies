# %% [markdown]
# # str veri tipi
# 1. Kaçış karakteri
# 2. Tanımlama
# 3. Erişim
# 4. Yardımcı fonksiyonlar

# %% [markdown]
# ## 1. Kaçış Karakteri (Escape Sequence). `\`

# %%
var1 = 'Ankara\'da'
var1 = '\talan'  # \t \n \b \a
print(var1)
# Out:
# 	alan

# %%
var1 = "C:\tarkan\nayır\nolamaz\ben\cok\kotuyum"
print(var1)
# Out:
# C:	arkan
# ayır
# en\cok\kotuyum

# %%
var1 = r"C:\tarkan\nayır\nolamaz\ben\cok\kotuyum" # raw string
print(var1)
# Out:
# C:\tarkan\nayır\nolamaz\ben\cok\kotuyum

# %%
var1 = "C:\\tarkan\\nayır\\nolamaz\\ben\\cok\\kotuyum" # raw string
print(var1)
# Out:
# C:\tarkan\nayır\nolamaz\ben\cok\kotuyum

# %%
print("Ali","Veli","İlkkan",sep="\n")
# Out:
# Ali
# Veli
# İlkkan

# %% [markdown]
# ## 2. Tanımlama

# %%
var1 = 'Python'
var2 = "Python"
var3 = """Python"""
print(type(var1),type(var2),type(var3))
# Out:
# <class 'str'> <class 'str'> <class 'str'>

# %% [markdown]
# ### 3. Erişim

# %%
var1 = "Python"
#       012345
#     -6-5-4-3-2-1

# %%
var1[2]
# Out:
# 't'

# %%
var1[0]
# Out:
# 'P'

# %%
var1 = "Python"
#       012345
#     -6-5-4-3-2-1
var1[-6]
# Out:
# 'P'

# %% [markdown]
# `degisken[baslangic:bitis:adim]`

# %%
var1[0:4] # indis numaraları 0 1 2 3
# Out:
# 'Pyth'

# %%
var1[:4]
# Out:
# 'Pyth'

# %%
var1[3:6]
# Out:
# 'hon'

# %%
var1[3:]
# Out:
# 'hon'

# %%
var1[:]
# Out:
# 'Python'

# %%
var1 = "Python"
#       012345
#     -6-5-4-3-2-1
var1[0:5:2] # 0 2 4
# Out:
# 'Pto'

# %%
var1[3:0:-1]
# Out:
# 'hty'

# %% [markdown]
# var1 = "Yaşamak"<br>
# Soru 1 => var1 'i kullanarak Yşmk çıktısını alabilmek için hangi kodu yazmalıyım<br>
# Soru 2 => var1 'i kullanarak aaa çıktısını alabilmek için hangi kodu yazmalıyım

# %%
var1 = "Yaşamak"
# Soru 1
print(var1[::2])
# Soru 2
print(var1[1::2])
# Out:
# Yşmk
# aaa

# %%
var1 = "Yaşamak"
##      0123456
#.     -7-6-5-4-3-2-1
var1[:3]
# Out:
# 'Yaş'

# %%
var1[1:-4],var1[1:3]
# Out:
# ('aş', 'aş')

# %% [markdown]
# ### 4. Yardımcı Fonksiyonlar
# * replace
# * split
# * strip
# * count
# * index
# * find

# %%
var1 = "Teşekkürler Süpermen"
var1.replace("e","ı",1).replace("ü","ı") #1 yazarak sadece 1 değişiklik yapmasını sağlayabiliriz
# Out:
# 'Tışekkırler Sıpermen'

# %%
var1 = "yaşamak"
var1[::-1]
# Out:
# 'kamaşay'

# %% [markdown]
# #################### çok önemli##########################
#
# str veri tipi immutable bir veri tipidir. bunun anlamı

# %%
var1= "yaşamak"
var1[0] = 'A'

# %% [markdown]
# yukarıdaki kod str veri tipi immutable bir veri tipi

# %% [markdown]
# split

# %%
var1 = "Ali;Veli;123123\n"
var1.split(";")
# Out:
# ['Ali', 'Veli', '123123\n']

# %%
var1 = "sadece cesurların işidir badana"
var1.split() #parametre girilemse de boşluk geçerlidir
# Out:
# ['sadece', 'cesurların', 'işidir', 'badana']

# %%
var1 = "_______aa_ss_bb_______jami_ryo_cc_________xx______"
var1.strip("_asbcxo")
lstrip -->
rstrip -->
# Out:
# 'jami_ry'

# %%
var1 = "çi pet pet pet pet"
var1.count("pet") #kaç tane pet kelimesinin geçtiğini gösterir
# Out:
# 4

# %% [markdown]
# index

# %%
  var1 = "başlangıç noktası"
  var1.index("a")
# Out:
# 1

# %%
var1 = "başlangıç noktası"
var1.rindex("lan")
# Out:
# 14

# %%
var1 = "başlangıç noktası"
var1.rindex("a")
# Out:
# 14

# %% [markdown]
# find

# %%
var1 = "başlangıç noktası"

var1.find
